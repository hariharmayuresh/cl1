# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets

data = pd.read_csv('Iris.csv')
data = data.drop("Id", axis=1)

x = data.drop("Species", axis=1)
wcss = []

for i in range(1,11):
    km = KMeans(n_clusters = i)
    km.fit(x)
    wcss.append(km.inertia_)

plt.plot(range(1,11),wcss,marker='o',linestyle='--')
plt.title("Elbow method")
plt.xlabel("number of clusters")
plt.ylabel('wcss')
plt.grid()
plt.show()
# Out:
# C:\Users\Vighnesh\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Vighnesh\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Vighnesh\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Based on the elbow method, choose the optimal number of clusters
optimal_clusters = 3  # In this case, it's clear that the optimal number of clusters is 3 for the Iris dataset

# Perform K-Means clustering with the optimal number of clusters
km = KMeans(n_clusters=optimal_clusters)
km.fit(x)

# Add cluster labels to the dataset
data['Cluster'] = km.labels_

# Visualize the clustered data with centroids
for cluster in range(optimal_clusters):
    cluster_data = data[data['Cluster'] == cluster]
    centroid = km.cluster_centers_[cluster]
    
    plt.scatter(cluster_data['SepalLengthCm'], cluster_data['SepalWidthCm'], label=f'Cluster {cluster}')
    plt.scatter(centroid[0], centroid[1], marker='x', s=100, label=f'Centroid {cluster}', color='red')

plt.title('K-Means Clustering with Centroids')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\Vighnesh\AppData\Roaming\Python\Python39\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
